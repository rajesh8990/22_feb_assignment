# %%
"""
Q.5 What are some common functions you can use to manipulate data in a Pandas DataFrame? Can
    you give an example of when you might use one of these functions?
    
    
Ans. Pandas provide some function we are use doing data Manipulate , data analytic etc in 
     DataFrame
     Some function Name :
     head(),tail(),columns(),dtypes() .etc
"""

# %%
# Example head()
""" 
head() and tail(): These function show the frist row data and last row data within a
                   data frame 
"""

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel("clean_file_excel.xlsx")

# %%
# use of head()
df.head()
# Out:
#    Unnamed: 0  Emp ID    Name Designation  Age Joining Date  Shift  \
# 0           0  EMP001  Name 1       Clerk   34   2020-01-01    Day
# 1           1  EMP002  Name 2  Accountant   23   2020-01-02  Night
# 2           2  EMP003  Name 3     Manager   34   2020-01-03    Day
# 3           3  EMP004  Name 4       Clerk   45   2020-01-04    Day
# 4           4  EMP005  Name 5  Accountant   54   2020-01-05  Night
#
#               Email  Basic Pay    DA  ...  Daily OT Hrs.  Total OT Hrs  \
# 0  Name 1@gmail.com      25000  4500  ...              2            50
# 1  Name 2@gmail.com      28000  5040  ...              1            26
# 2  Name 3@gmail.com      40000  7200  ...              1            30
# 3  Name 4@gmail.com      23000  4140  ...              1            30
# 4  Name 5@gmail.com      28000  5040  ...              1            30
#
#        OT Pay    OT Salary  Gross Salary   PT    PF  Advance  Tota Deduction  \
# ...

# %%
# Use of tail()
df.tail()
# Out:
#      Unnamed: 0  Emp ID      Name Designation  Age Joining Date  Shift  \
# 473         473  EMP474  Name 474  Accountant   34   2020-01-18  Night
# 474         474  EMP475  Name 475  Accountant   43   2020-01-19  Night
# 475         475  EMP476  Name 476  Accountant   34   2020-01-20  Night
# 476         476  EMP477  Name 477     Manager   43   2020-01-21    Day
# 477         477  EMP478  Name 478       Clerk   23   2020-01-22    Day
#
#                   Email  Basic Pay    DA  ...  Daily OT Hrs.  Total OT Hrs  \
# 473  Name 474@gmail.com      34000  6120  ...              2            60
# 474  Name 475@gmail.com      45000  8100  ...              0             0
# 475  Name 476@gmail.com      55000  9900  ...              1            30
# 476  Name 477@gmail.com      43000  7740  ...              1            27
# 477  Name 478@gmail.com      25000  4500  ...              0             0
#
#          OT Pay  OT Salary  Gross Salary   PT    PF  Advance  Tota Deduction  \
# ...

# %%
# Use of columns
"""columns is used to retrieve the column labels (names) of a DataFrame."""
df.columns
# Out:
# Index(['Unnamed: 0', 'Emp ID', 'Name', 'Designation', 'Age', 'Joining Date',
#        'Shift', 'Email', 'Basic Pay', 'DA', 'HRA', 'CA', 'TA', 'MA', 'AT',
#        'Salary', 'Daily OT Hrs.', 'Total OT Hrs', 'OT Pay', 'OT Salary',
#        'Gross Salary', 'PT', 'PF', 'Advance', 'Tota Deduction', 'Net Salary'],
#       dtype='object')

# %%
# define dataframe  of data types
df.dtypes
# Out:
# Unnamed: 0                 int64
# Emp ID                    object
# Name                      object
# Designation               object
# Age                        int64
# Joining Date      datetime64[ns]
# Shift                     object
# Email                     object
# Basic Pay                  int64
# DA                         int64
# HRA                        int64
# CA                         int64
# TA                         int64
# MA                         int64
# AT                         int64
# Salary                   float64
# Daily OT Hrs.              int64
# Total OT Hrs               int64
# OT Pay                   float64
# OT Salary                float64
# Gross Salary             float64
# PT                         int64
# PF                         int64
# Advance                  float64
# Tota Deduction             int64
# Net Salary               float64
# dtype: object
